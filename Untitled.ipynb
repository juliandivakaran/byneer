# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo in c:\users\user\appdata\roaming\python\python312\site-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pymongo) (2.7.0)

# %%
import pymongo
import pandas as pd
#from urlib.parse import quote_plus
from urllib.parse import quote_plus
import numpy as np


username = "cypsolabs"
password ="@testing01"
encoded_username= quote_plus(username)
encoded_password = quote_plus(password)

MONGO_URI =f"mongodb+srv://{encoded_username}:{encoded_password}@byner.vxp0o.mongodb.net/?retryWrites=true&w=majority&appName=byner"

client = pymongo.MongoClient(MONGO_URI)
db = client['testdb']
collection = db['newdb']

data = collection.find()

df = pd.DataFrame(list(data))

df.head()
# Out:
#                         _id                   timestamp  number  index  trend  \
# 0  679aa357d721424728c1d560  2025-01-29T13:53:26.496843       1  23121    NaN
# 1  679aa35ad721424728c1d561  2025-01-29T13:53:29.644197       7  23122    1.0
# 2  679aa35cd721424728c1d562  2025-01-29T13:53:32.389285       3  23123   -1.0
# 3  679aa35ed721424728c1d563  2025-01-29T13:53:34.239919       4  23124    1.0
# 4  679aa35fd721424728c1d564  2025-01-29T13:53:35.706547       2  23125   -1.0
#
#   market_indicator indicator  good_number  bad_number neutral_number  \
# 0             GOOD       bad          NaN         1.0           None
# 1             None       bad          NaN         7.0           None
# 2             None      good          3.0         NaN           None
# 3             None       bad          NaN         4.0           None
# 4             None       bad          NaN         2.0           None
#
#    digit_up  digit_down       digit_colors
# 0       NaN         NaN  digits_moved_down
# 1       7.0         NaN  digits_moved_down
# 2       NaN         3.0    digits_moved_up
# 3       4.0         NaN  digits_moved_down
# 4       NaN         2.0  digits_moved_down

# %%
df.describe()
# Out:
#             number         index        trend  good_number   bad_number  \
# count  5078.000000   5078.000000  5070.000000  2585.000000  2493.000000
# mean      4.507286  24084.295983    -0.006312     4.557447     4.455275
# std       2.872281    674.568020     1.000079     2.877512     2.866496
# min       0.000000  23121.000000    -1.000000     0.000000     0.000000
# 25%       2.000000  23522.000000    -1.000000     2.000000     2.000000
# 50%       5.000000  23921.500000    -1.000000     5.000000     4.000000
# 75%       7.000000  24721.750000     1.000000     7.000000     7.000000
# max       9.000000  25589.000000     1.000000     9.000000     9.000000
#
#           digit_up   digit_down
# count  2519.000000  2551.000000
# mean      6.319571     2.725206
# std       2.232668     2.246075
# min       1.000000     0.000000
# 25%       5.000000     1.000000
# 50%       7.000000     2.000000
# 75%       8.000000     4.000000
# max       9.000000     8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5078 entries, 0 to 5077
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               5078 non-null   object
#  1   timestamp         5078 non-null   object
#  2   number            5078 non-null   int64
#  3   index             5078 non-null   int64
#  4   trend             5070 non-null   float64
#  5   market_indicator  1135 non-null   object
#  6   indicator         5078 non-null   object
#  7   good_number       2585 non-null   float64
#  8   bad_number        2493 non-null   float64
#  9   neutral_number    0 non-null      object
#  10  digit_up          2519 non-null   float64
#  11  digit_down        2551 non-null   float64
#  12  digit_colors      5078 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 515.9+ KB

# %%
df = df.drop("_id", axis=1)

# %%
df['trend'] = df['trend'].fillna(0).astype(int)
df['good_number'] = df['good_number'].fillna(0).astype(int)
df['bad_number'] = df['bad_number'].fillna(0).astype(int)
df['digit_up'] = df['digit_up'].fillna(0).astype(int)
df['digit_down'] = df['digit_down'].fillna(0).astype(int)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

# First subplot: Trend, good_number, bad_number
plt.subplot(1, 2, 1)
plt.plot(df['index'], df['trend'], color='red', label='trend')
plt.plot(df['index'], df['good_number'], color='green', label='good_number')
plt.plot(df['index'], df['bad_number'], color='blue', label='bad_number')
plt.title('Stock Analysis')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend(loc='best')

# Second subplot: digit_up and digit_down
plt.subplot(1, 2, 2)
plt.plot(df['index'], df['digit_up'], color='black', label='digit_up')
plt.plot(df['index'], df['digit_down'], color='purple', label='digit_down')
plt.title('Digit Changes')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5078 entries, 0 to 5077
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         5078 non-null   object
#  1   number            5078 non-null   int64
#  2   index             5078 non-null   int64
#  3   trend             5078 non-null   int32
#  4   market_indicator  1135 non-null   object
#  5   indicator         5078 non-null   object
#  6   good_number       5078 non-null   int32
#  7   bad_number        5078 non-null   int32
#  8   neutral_number    0 non-null      object
#  9   digit_up          5078 non-null   int32
#  10  digit_down        5078 non-null   int32
#  11  digit_colors      5078 non-null   object
# dtypes: int32(5), int64(2), object(5)
# memory usage: 377.0+ KB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming `df` is your DataFrame
# Handle 'market_indicator' (convert to float or encode)
df['market_indicator'] = pd.to_numeric(df['market_indicator'], errors='coerce')  # Convert to numeric, NaN for invalid

# Handle 'indicator' (if it contains categorical data, use Label Encoding)
le = LabelEncoder()
df['indicator'] = le.fit_transform(df['indicator'].astype(str))

# Handle 'neutral_number' (since it has no non-null values, it can be dropped)
df.drop('neutral_number', axis=1, inplace=True)

# Handle 'digit_colors' (if it is categorical, convert to numeric via Label Encoding)
df['digit_colors'] = le.fit_transform(df['digit_colors'].astype(str))

# Check the result
print(df.head())

# Now you can convert the entire DataFrame to numeric types
df = df.apply(pd.to_numeric, errors='ignore')  # Non-numeric columns remain unchanged

# Verify types
print(df.dtypes)
# Out:
#                     timestamp  number  index  trend  market_indicator  \
# 0  2025-01-29T13:53:26.496843       1  23121      0               NaN
# 1  2025-01-29T13:53:29.644197       7  23122      1               NaN
# 2  2025-01-29T13:53:32.389285       3  23123     -1               NaN
# 3  2025-01-29T13:53:34.239919       4  23124      1               NaN
# 4  2025-01-29T13:53:35.706547       2  23125     -1               NaN
#
#    indicator  good_number  bad_number  digit_up  digit_down  digit_colors
# 0          0            0           1         0           0             0
# 1          0            0           7         7           0             0
# 2          1            3           0         0           3             1
# 3          0            0           4         4           0             0
# 4          0            0           2         0           2             0
# timestamp            object
# number                int64
# index                 int64
# trend                 int32
# market_indicator    float64
# indicator             int32
# good_number           int32
# bad_number            int32
# digit_up              int32
# digit_down            int32
# digit_colors          int32
# dtype: object
# C:\Users\user\AppData\Local\Temp\ipykernel_9648\1504512808.py:22: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')  # Non-numeric columns remain unchanged

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Convert to float by calculating the number of seconds since the UNIX epoch
df['timestamp'] = df['timestamp'].astype(np.int64) / 1e9  # Convert to seconds as float

# %%
import numpy as np
import sklearn
import sklearn.preprocessing
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

valid_set_size_percentage = 10
test_set_size_percentage = 10

def normalize_data(df):
    min_max_scaler = sklearn.preprocessing.MinMaxScaler()

    # Normalize all 14 required features
    for feature in ['good_number', 'bad_number', 'digit_up', 'digit_down', ...]:  # Add all features here
        if feature in df.columns:
            df[feature] = min_max_scaler.fit_transform(df[feature].values.reshape(-1, 1))

    return df


def load_data(stock, seq_len):
    data_raw = stock.values  # Using .values instead of .as_matrix()
    data = []

    for index in range(len(data_raw) - seq_len):
        data.append(data_raw[index: index + seq_len])
    data = np.array(data)

    valid_set_size = int(np.round(valid_set_size_percentage / 100 * data.shape[0]))
    test_set_size = int(np.round(test_set_size_percentage / 100 * data.shape[0]))
    train_set_size = data.shape[0] - (valid_set_size + test_set_size)

    x_train = data[:train_set_size, :-1, :]
    y_train = data[:train_set_size, -1, :]

    x_valid = data[train_set_size:train_set_size + valid_set_size, :-1, :]
    y_valid = data[train_set_size:train_set_size + valid_set_size, -1, :]

    x_test = data[train_set_size + valid_set_size:, :-1, :]
    y_test = data[train_set_size + valid_set_size:, -1, :]

    return [x_train, y_train, x_valid, y_valid, x_test, y_test]

df_stock = df[df['indicator'] == 'good'].copy()

digit_colors_encoded = pd.get_dummies(df_stock['digit_colors'], prefix='digit_colors')
df_stock = pd.get_dummies(df_stock, columns=['trend'], prefix=['trend']) # Assuming 'trend' column has 'NEUTRAL'
df_stock = pd.concat([df_stock, digit_colors_encoded], axis=1)
df_stock.drop(['digit_colors'], axis=1, inplace=True)
df_stock.drop(['indicator'], axis=1, inplace=True)
df_stock.drop(['number'], axis=1, inplace=True)
df_stock = df.drop(['indicator', 'number'], axis=1)  # Drop if they haven't already been dropped
df_stock_norm = df_stock.copy()
df_stock_norm = normalize_data(df_stock_norm)

# Normalize stock
df_stock_norm = df_stock.copy()
df_stock_norm = normalize_data(df_stock_norm)

# Create train, test data
seq_len = 20  # Choose sequence length
x_train, y_train, x_valid, y_valid, x_test, y_test = load_data(df_stock_norm, seq_len)

# Print shapes
print('x_train.shape = ', x_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_valid.shape = ', x_valid.shape)
print('y_valid.shape = ', y_valid.shape)
print('x_test.shape = ', x_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (4046, 19, 9)
# y_train.shape =  (4046, 9)
# x_valid.shape =  (506, 19, 9)
# y_valid.shape =  (506, 9)
# x_test.shape =  (506, 19, 9)
# y_test.shape =  (506, 9)

# %%
plt.figure(figsize=(15, 5));
plt.plot(df_stock_norm.digit_up.values, color='red', label='digit_up')
plt.plot(df_stock_norm.digit_up.values, color='green', label='digit_down')
plt.plot(df_stock_norm.low.values, color='blue', label='low')
plt.plot(df_stock_norm.high.values, color='black', label='high')
#plt.plot(df_stock_norm.volume.values, color='gray', label='volume')
plt.title('stock')
plt.xlabel('time [days]')
plt.ylabel('normalized price/volume')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9648\341183636.py in ?()
#       1 plt.figure(figsize=(15, 5));
#       2 plt.plot(df_stock_norm.digit_up.values, color='red', label='digit_up')
#       3 plt.plot(df_stock_norm.digit_up.values, color='green', label='digit_down')
# ----> 4 plt.plot(df_stock_norm.low.values, color='blue', label='low')
#       5 plt.plot(df_stock_norm.high.values, color='black', label='high')
#       6 #plt.plot(df_stock_norm.volume.values, color='gray', label='volume')
#       7 plt.title('stock')
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'low'

# %%
plt.figure(figsize=(15, 5));
plt.plot(df_stock_norm.index, df_stock_norm['digit_up'], color='red', label='digit_up') # Replaced df_stock_norm.open with df_stock_norm['digit_up']
plt.plot(df_stock_norm.index, df_stock_norm['digit_down'], color='green', label='digit_down') # Replaced df_stock_norm.close with df_stock_norm['digit_down']
plt.plot(df_stock_norm.index, df_stock_norm['good_number'], color='blue', label='good_number') # Replaced df_stock_norm.low with df_stock_norm['good_number']
plt.plot(df_stock_norm.index, df_stock_norm['bad_number'], color='black', label='bad_number') # Replaced df_stock_norm.high with df_stock_norm['bad_number']
#plt.plot(df_stock_norm.volume.values, color='gray', label='volume') # This line is still commented out as 'volume' is not present in the dataframe
plt.title('stock')
plt.xlabel('time [days]')
plt.ylabel('normalized price/volume')
plt.legend(loc='best')
plt.show()

# %%
perm_array = np.arange(y_train.shape[0])
np.random.shuffle(perm_array)

# function to get the next batch
def get_next_batch(batch_size):
    global index_in_epoch, x_train, y_train, perm_array
    start = index_in_epoch
    index_in_epoch += batch_size

    if index_in_epoch > y_train.shape[0]: # Condition should be based on y_train's size
        np.random.shuffle(perm_array) # shuffle permutation array
        start = 0 # start next epoch
        index_in_epoch = batch_size

    end = index_in_epoch

    # Use perm_array to index both x_train and y_train consistently
    return x_train[perm_array[start:end]], y_train[perm_array[start:end]]

# %%
n_steps = seq_len - 1
n_inputs = 9  # Updated to match the actual number of features
n_neurons = 200
n_outputs = 9  # Updated to match the actual number of features
n_layers = 2
learning_rate = 0.001
batch_size = 50
n_epochs = 100
train_set_size = x_train.shape[0]
test_set_size = x_test.shape[0]


tf.compat.v1.reset_default_graph()
tf.compat.v1.disable_eager_execution()
# Out:
# WARNING:tensorflow:From C:\Users\user\AppData\Local\Temp\ipykernel_9648\4203936510.py:13: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
df_stock = df[df['indicator'] != 'bad'].copy() # Only keep rows where 'indicator' is not 'bad'
#df_stock = df[df['indicator'] == 'good'].copy()
df_stock.drop(['indicator'], axis=1, inplace=True)
df_stock.drop(['number'], axis=1, inplace=True)

# %%
df_stock = df[df['digit_colors'] != 'digits_moved_up'].copy() # Only keep rows where 'indicator' is not 'bad'
#df_stock = df[df['indicator'] == 'good'].copy()
df_stock.drop(['digit_colors'], axis=1, inplace=True)
df_stock.drop(['number'], axis=1, inplace=True)

# %%
from tensorflow.keras.layers import SimpleRNNCell

X = tf.compat.v1.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.compat.v1.placeholder(tf.float32, [None, n_outputs])

# use Basic RNN Cell
layers = [SimpleRNNCell(units=n_neurons, activation='elu')
          for layer in range(n_layers)]

# Then, use tf.keras.layers.RNN to create the RNN:
multi_layer_cell = tf.keras.layers.RNN(layers, return_sequences=True)
rnn_outputs = multi_layer_cell(X)

# Reshape the outputs and define the fully connected layer using tf.keras.layers.Dense
stacked_rnn_outputs = tf.reshape(rnn_outputs, [-1, n_neurons])
stacked_outputs = tf.keras.layers.Dense(n_outputs)(stacked_rnn_outputs)

outputs = tf.reshape(stacked_outputs, [-1, n_steps, n_outputs])
outputs = outputs[:,n_steps-1,:] # keep only last output of sequence

# %%
loss = tf.reduce_mean(tf.square(outputs - y)) # loss function = mean squared error
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate) # Changed to tf.compat.v1.train.AdamOptimizer
training_op = optimizer.minimize(loss)
# Out:
# WARNING:tensorflow:From C:\Users\user\AppData\Local\Temp\ipykernel_9648\2888249373.py:2: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %%
# Replace NaNs with zeros (or use another value like np.nanmean for mean)
x_train = np.nan_to_num(x_train, nan=0.0)
y_train = np.nan_to_num(y_train, nan=0.0)

# %%
# Fill NaN values with 0
x_valid = np.nan_to_num(x_valid, nan=0)
y_valid = np.nan_to_num(y_valid, nan=0)

# %%
print("x_batch shape:", x_batch.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print("x_batch shape:", x_batch.shape)
#
# NameError: name 'x_batch' is not defined

# %%
training_loss = []
validation_loss = []
index_in_epoch = 0
epochs_completed = 0
saver = tf.compat.v1.train.Saver()

with tf.compat.v1.Session() as sess: # Changed to tf.compat.v1.Session()
    sess.run(tf.compat.v1.global_variables_initializer()) # Changed to tf.compat.v1.global_variables_initializer()
    for iteration in range(int(n_epochs*train_set_size/batch_size)):
        x_batch, y_batch = get_next_batch(batch_size) # fetch the next training batch 
        sess.run(training_op, feed_dict={X: x_batch, y: y_batch}) 
        if iteration % int(5*train_set_size/batch_size) == 0:
            mse_train = loss.eval(feed_dict={X: x_train, y: y_train}) 
            mse_valid = loss.eval(feed_dict={X: x_valid, y: y_valid}) 
            print('%.2f epochs: MSE train/valid = %.6f/%.6f'%(
                iteration*batch_size/train_set_size, mse_train, mse_valid))
            training_loss.append(mse_train)
            validation_loss.append(mse_valid)
    
    y_train_pred = sess.run(outputs, feed_dict={X: x_train})
    y_valid_pred = sess.run(outputs, feed_dict={X: x_valid})

    y_train_pred = sess.run(outputs, feed_dict={X: x_train})
    y_valid_pred = sess.run(outputs, feed_dict={X: x_valid})
    y_test_pred = sess.run(outputs, feed_dict={X: x_test})
    saver.save(sess, 'model.ckpt')


plt.plot(training_loss, label="Train Loss")
plt.plot(validation_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.show()
# Out:
# 0.00 epochs: MSE train/valid = 207914178478866432.000000/207921548642746368.000000
# 4.99 epochs: MSE train/valid = 84991.367188/187462.937500
# 9.99 epochs: MSE train/valid = 99675.437500/221535.265625
# 14.98 epochs: MSE train/valid = 131040.617188/211144.031250
# 19.97 epochs: MSE train/valid = 145110.781250/111225.500000
# 24.96 epochs: MSE train/valid = 801072896.000000/806980032.000000
# 29.96 epochs: MSE train/valid = 570011520.000000/565273984.000000
# 34.95 epochs: MSE train/valid = 22258466.000000/22720880.000000
# 39.94 epochs: MSE train/valid = 16380721.000000/16851366.000000
# 44.93 epochs: MSE train/valid = 455525.500000/521564.125000
# 49.93 epochs: MSE train/valid = 3007535616.000000/3014994688.000000
# 54.92 epochs: MSE train/valid = 5284283.000000/6059521.000000
# 59.91 epochs: MSE train/valid = 886977.000000/1043317.062500
# 64.90 epochs: MSE train/valid = 27695187968.000000/27707729920.000000
# 69.90 epochs: MSE train/valid = 11233875984384.000000/11234266054656.000000
# 74.89 epochs: MSE train/valid = 5192912.500000/4662738.000000
# 79.88 epochs: MSE train/valid = 66755698688.000000/66766696448.000000
# 84.87 epochs: MSE train/valid = 6756681908224.000000/6756604837888.000000
# 89.87 epochs: MSE train/valid = 43422912512.000000/43397185536.000000
# 94.86 epochs: MSE train/valid = 5395443089408.000000/5395645464576.000000
# 99.85 epochs: MSE train/valid = 93904.656250/118384.851562

# %%
with tf.compat.v1.Session() as sess:
    # Restore the model's state
    saver = tf.compat.v1.train.Saver()
    saver.restore(sess, 'model.ckpt')

    # Predict using the trained model
    y_train_pred = sess.run(outputs, feed_dict={X: x_train})
    y_valid_pred = sess.run(outputs, feed_dict={X: x_valid})
    y_test_pred = sess.run(outputs, feed_dict={X: x_test})

    # Optionally, evaluate the performance (e.g., MSE)
    mse_test = loss.eval(feed_dict={X: x_test, y: y_test})
    print("MSE on test data: %.6f" % mse_test)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt
# MSE on test data: nan

# %%
import numpy as np

# Check for NaN or Inf in the data
if np.any(np.isnan(x_test)) or np.any(np.isinf(x_test)):
    print("x_test contains NaN or Inf values")
if np.any(np.isnan(y_test)) or np.any(np.isinf(y_test)):
    print("y_test contains NaN or Inf values")
# Out:
# x_test contains NaN or Inf values
# y_test contains NaN or Inf values

# %%
# Replace NaN and Inf with 0
x_test = np.nan_to_num(x_test, nan=0.0, posinf=0.0, neginf=0.0)
y_test = np.nan_to_num(y_test, nan=0.0, posinf=0.0, neginf=0.0)

# %%
# Replace NaN/Inf with mean of the column
for i in range(x_test.shape[1]):  # Iterate through each feature column
    col_mean = np.nanmean(x_test[:, i])  # Calculate the column mean
    x_test[np.isnan(x_test[:, i]) | np.isinf(x_test[:, i]), i] = col_mean

# Similarly for y_test
y_test_mean = np.nanmean(y_test)
y_test[np.isnan(y_test) | np.isinf(y_test)] = y_test_mean
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 for i in range(x_test.shape[1]):  # Iterate through each feature column
#       3     col_mean = np.nanmean(x_test[:, i])  # Calculate the column mean
# ----> 4     x_test[np.isnan(x_test[:, i]) | np.isinf(x_test[:, i]), i] = col_mean
#       6 # Similarly for y_test
#       7 y_test_mean = np.nanmean(y_test)
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 19 but corresponding boolean dimension is 9

# %%
# Check again after cleaning
if np.any(np.isnan(x_test_clean)) or np.any(np.isinf(x_test_clean)):
    print("There are still NaN or Inf values in x_test.")
if np.any(np.isnan(y_test_clean)) or np.any(np.isinf(y_test_clean)):
    print("There are still NaN or Inf values in y_test.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Check again after cleaning
# ----> 2 if np.any(np.isnan(x_test_clean)) or np.any(np.isinf(x_test_clean)):
#       3     print("There are still NaN or Inf values in x_test.")
#       4 if np.any(np.isnan(y_test_clean)) or np.any(np.isinf(y_test_clean)):
#
# NameError: name 'x_test_clean' is not defined

# %%
# Check the shape of x_train and x_valid
print('x_train shape: ', x_train.shape)
print('x_valid shape: ', x_valid.shape)

# Ensure the shape of x_batch matches (None, 19, 14)
# If needed, modify the data to include the correct number of features
# Out:
# x_train shape:  (4046, 19, 9)
# x_valid shape:  (506, 19, 9)

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test[:100], label="Actual")
plt.plot(y_test_pred[:100], label="Predicted")
plt.legend()
plt.title("Predicted vs Actual Values")
plt.show()

# %%
# Create a saver object to save variables
saver = tf.compat.v1.train.Saver()

# Save the model's state
saver.save(sess, 'model.ckpt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 5
#       2 saver = tf.compat.v1.train.Saver()
#       4 # Save the model's state
# ----> 5 saver.save(sess, 'model.ckpt')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\training\saver.py:1288, in Saver.save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs, save_debug_info)
#    1286   model_checkpoint_path = self.saver_def.save_tensor_name
#    1287 else:
# -> 1288   model_checkpoint_path = sess.run(
#    1289       self.saver_def.save_tensor_name,
#    1290       {self.saver_def.filename_tensor_name: checkpoint_file})
#    1292 model_checkpoint_path = compat.as_str(model_checkpoint_path)
#    1293 if write_state:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\client\session.py:1145, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1143 # Check session.
#    1144 if self._closed:
# -> 1145   raise RuntimeError('Attempted to use a closed Session.')
#    1146 if self.graph.version == 0:
#    1147   raise RuntimeError('The Session graph is empty. Add operations to the '
#    1148                      'graph before calling run().')
#
# RuntimeError: Attempted to use a closed Session.

# %%
import pickle

# Save the model
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Load the model
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 # Save the model
#       4 with open('model.pkl', 'wb') as f:
# ----> 5     pickle.dump(model, f)
#       7 # Load the model
#       8 with open('model.pkl', 'rb') as f:
#
# NameError: name 'model' is not defined
